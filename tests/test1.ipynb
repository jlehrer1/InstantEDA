# %%
import pandas as pd 
import plotly.graph_objects as go
import os
from sklearn.impute import KNNImputer, SimpleImputer
import warnings
import numpy as np
import sys, os
sys.path.append(os.path.abspath('../cleaning'))
import clean

# %%
df = pd.read_csv('dengue_features_train.csv')
df_clean = pd.read_csv('dengue_features_train_CLEAN.csv').dropna()
df = clean.clean(df, categorical_all=True)
df
# Out:
#       city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0        0  1990           0      1990-04-30  0.122600  0.103725  0.198483
# 1        0  1990           0      1990-05-07  0.169900  0.142175  0.162357
# 2        0  1990           0      1990-05-14  0.032250  0.172967  0.157200
# 3        0  1990           0      1990-05-21  0.128633  0.245067  0.227557
# 4        0  1990           0      1990-05-28  0.196200  0.262200  0.251200
# ...    ...   ...         ...             ...       ...       ...       ...
# 1451     1  2010           0      2010-05-28  0.342750  0.318900  0.256343
# 1452     1  2010           0      2010-06-04  0.160157  0.160371  0.136043
# 1453     1  2010           0      2010-06-11  0.247057  0.146057  0.250357
# 1454     1  2010           0      2010-06-18  0.333914  0.245771  0.278886
# 1455     1  2010           0      2010-06-25  0.298186  0.232971  0.274214
#
#        ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# ...
